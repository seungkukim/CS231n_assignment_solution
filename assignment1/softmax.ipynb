# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside `cs231n/classifiers/softmax.py`.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.348635
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.331897 analytic: -0.331897, relative error: 4.030949e-08
# numerical: 1.626098 analytic: 1.626098, relative error: 2.964377e-08
# numerical: 1.092470 analytic: 1.092470, relative error: 2.425924e-08
# numerical: 0.171551 analytic: 0.171551, relative error: 1.200094e-09
# numerical: 0.527484 analytic: 0.527484, relative error: 4.196541e-08
# numerical: -2.096103 analytic: -2.096103, relative error: 9.896723e-09
# numerical: -0.480302 analytic: -0.480302, relative error: 3.837213e-08
# numerical: -2.510297 analytic: -2.510298, relative error: 1.508246e-08
# numerical: -0.543706 analytic: -0.543706, relative error: 4.345928e-08
# numerical: -1.737106 analytic: -1.737106, relative error: 4.856257e-08
# numerical: -0.461271 analytic: -0.461271, relative error: 4.972312e-08
# numerical: 0.541419 analytic: 0.541419, relative error: 3.208724e-08
# numerical: -2.214095 analytic: -2.214095, relative error: 3.577509e-08
# numerical: 3.023471 analytic: 3.023471, relative error: 2.601716e-08
# numerical: -2.493187 analytic: -2.493187, relative error: 2.126594e-08
# numerical: 0.715481 analytic: 0.715481, relative error: 2.810999e-08
# numerical: 1.148117 analytic: 1.148117, relative error: 2.424524e-08
# numerical: -2.020686 analytic: -2.020686, relative error: 1.324437e-08
# numerical: 2.432606 analytic: 2.432606, relative error: 1.740430e-08
# numerical: -0.171607 analytic: -0.171607, relative error: 2.236170e-07

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.348635e+00 computed in 0.032275s
# vectorized loss: 2.348635e+00 computed in 0.005700s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.

from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################

# Provided as a reference. You may or may not want to change these hyperparameters
learning_rates = [5e-8, 1e-7, 2e-7, 3e-7]
regularization_strengths = [1.25e4, 2.5e4, 5e4, 7.5e4]

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
num_training, num_validation = X_train.shape[0], X_val.shape[0]

for lr in learning_rates:
    for rs in regularization_strengths:
        sm = Softmax()
        sm.train(X_train, y_train, learning_rate=lr, reg=rs,
                      num_iters=3000, verbose=True)

        y_train_pred = sm.predict(X_train)
        y_val_pred = sm.predict(X_val)

        train_num_current = np.sum(y_train == y_train_pred)
        val_num_current = np.sum(y_val == y_val_pred)
        
        train_accuracy = float(train_num_current) / num_training
        validation_accuracy = float(val_num_current) / num_validation

        if best_val < validation_accuracy:
            best_val = validation_accuracy
            best_softmax = sm

        results[(lr, rs)] = (train_accuracy, validation_accuracy)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 3000: loss 5.304167
# iteration 100 / 3000: loss 4.248979
# iteration 200 / 3000: loss 4.293150
# iteration 300 / 3000: loss 4.059762
# iteration 400 / 3000: loss 3.698288
# iteration 500 / 3000: loss 3.601414
# iteration 600 / 3000: loss 3.317924
# iteration 700 / 3000: loss 3.423964
# iteration 800 / 3000: loss 3.313338
# iteration 900 / 3000: loss 3.397543
# iteration 1000 / 3000: loss 3.190679
# iteration 1100 / 3000: loss 3.065925
# iteration 1200 / 3000: loss 3.071900
# iteration 1300 / 3000: loss 2.922863
# iteration 1400 / 3000: loss 2.754498
# iteration 1500 / 3000: loss 2.744040
# iteration 1600 / 3000: loss 2.928672
# iteration 1700 / 3000: loss 2.739228
# iteration 1800 / 3000: loss 2.453107
# iteration 1900 / 3000: loss 2.719811
# iteration 2000 / 3000: loss 2.739716
# iteration 2100 / 3000: loss 2.789755
# iteration 2200 / 3000: loss 2.947656
# iteration 2300 / 3000: loss 2.835837
# iteration 2400 / 3000: loss 2.804126
# iteration 2500 / 3000: loss 2.395473
# iteration 2600 / 3000: loss 2.629662
# iteration 2700 / 3000: loss 2.411982
# iteration 2800 / 3000: loss 2.710301
# iteration 2900 / 3000: loss 2.584956
# iteration 0 / 3000: loss 6.208515
# iteration 100 / 3000: loss 4.539633
# iteration 200 / 3000: loss 4.262931
# iteration 300 / 3000: loss 3.591100
# iteration 400 / 3000: loss 3.642512
# iteration 500 / 3000: loss 3.698668
# iteration 600 / 3000: loss 3.241652
# iteration 700 / 3000: loss 3.024130
# iteration 800 / 3000: loss 3.216182
# iteration 900 / 3000: loss 3.112574
# iteration 1000 / 3000: loss 3.025329
# iteration 1100 / 3000: loss 3.063954
# iteration 1200 / 3000: loss 2.918716
# iteration 1300 / 3000: loss 3.236395
# iteration 1400 / 3000: loss 2.960407
# iteration 1500 / 3000: loss 2.785713
# iteration 1600 / 3000: loss 2.449345
# iteration 1700 / 3000: loss 2.719591
# iteration 1800 / 3000: loss 2.969981
# iteration 1900 / 3000: loss 2.743590
# iteration 2000 / 3000: loss 2.716363
# iteration 2100 / 3000: loss 2.757094
# iteration 2200 / 3000: loss 2.719539
# iteration 2300 / 3000: loss 2.668646
# iteration 2400 / 3000: loss 2.911819
# iteration 2500 / 3000: loss 2.820539
# iteration 2600 / 3000: loss 2.600030
# iteration 2700 / 3000: loss 2.451801
# iteration 2800 / 3000: loss 2.539445
# iteration 2900 / 3000: loss 2.678924
# iteration 0 / 3000: loss 6.524339
# iteration 100 / 3000: loss 4.451206
# iteration 200 / 3000: loss 4.126380
# iteration 300 / 3000: loss 3.846020
# iteration 400 / 3000: loss 3.792230
# iteration 500 / 3000: loss 3.855196
# iteration 600 / 3000: loss 3.488932
# iteration 700 / 3000: loss 3.215053
# iteration 800 / 3000: loss 3.366528
# iteration 900 / 3000: loss 3.051233
# iteration 1000 / 3000: loss 3.443577
# iteration 1100 / 3000: loss 2.836050
# iteration 1200 / 3000: loss 3.010816
# iteration 1300 / 3000: loss 3.113509
# iteration 1400 / 3000: loss 2.914628
# iteration 1500 / 3000: loss 2.932467
# iteration 1600 / 3000: loss 2.810005
# iteration 1700 / 3000: loss 2.804628
# iteration 1800 / 3000: loss 2.803103
# iteration 1900 / 3000: loss 2.927733
# iteration 2000 / 3000: loss 2.692642
# iteration 2100 / 3000: loss 2.767896
# iteration 2200 / 3000: loss 2.476454
# iteration 2300 / 3000: loss 2.660142
# iteration 2400 / 3000: loss 2.755483
# iteration 2500 / 3000: loss 2.605810
# iteration 2600 / 3000: loss 2.672199
# iteration 2700 / 3000: loss 2.445626
# iteration 2800 / 3000: loss 3.036449
# iteration 2900 / 3000: loss 2.497644
# iteration 0 / 3000: loss 5.428597
# iteration 100 / 3000: loss 4.546125
# iteration 200 / 3000: loss 4.180181
# iteration 300 / 3000: loss 3.660835
# iteration 400 / 3000: loss 3.830523
# iteration 500 / 3000: loss 3.605119
# iteration 600 / 3000: loss 3.555711
# iteration 700 / 3000: loss 3.234810
# iteration 800 / 3000: loss 3.184401
# iteration 900 / 3000: loss 3.112504
# iteration 1000 / 3000: loss 3.024401
# iteration 1100 / 3000: loss 3.127222
# iteration 1200 / 3000: loss 2.663645
# iteration 1300 / 3000: loss 2.910289
# iteration 1400 / 3000: loss 2.755390
# iteration 1500 / 3000: loss 2.929495
# iteration 1600 / 3000: loss 2.956521
# iteration 1700 / 3000: loss 2.867353
# iteration 1800 / 3000: loss 2.963071
# iteration 1900 / 3000: loss 2.645497
# iteration 2000 / 3000: loss 2.779414
# iteration 2100 / 3000: loss 2.738137
# iteration 2200 / 3000: loss 2.781500
# iteration 2300 / 3000: loss 2.581788
# iteration 2400 / 3000: loss 2.594563
# iteration 2500 / 3000: loss 2.577255
# iteration 2600 / 3000: loss 2.608108
# iteration 2700 / 3000: loss 2.724807
# iteration 2800 / 3000: loss 2.494714
# iteration 2900 / 3000: loss 2.690504
# iteration 0 / 3000: loss 6.117444
# iteration 100 / 3000: loss 3.984719
# iteration 200 / 3000: loss 3.850965
# iteration 300 / 3000: loss 3.319305
# iteration 400 / 3000: loss 3.465888
# iteration 500 / 3000: loss 3.228172
# iteration 600 / 3000: loss 3.108758
# iteration 700 / 3000: loss 2.977786
# iteration 800 / 3000: loss 3.029772
# iteration 900 / 3000: loss 2.489140
# iteration 1000 / 3000: loss 2.940484
# iteration 1100 / 3000: loss 2.690330
# iteration 1200 / 3000: loss 2.699584
# iteration 1300 / 3000: loss 2.690435
# iteration 1400 / 3000: loss 2.431059
# iteration 1500 / 3000: loss 2.502541
# iteration 1600 / 3000: loss 2.762088
# iteration 1700 / 3000: loss 2.527505
# iteration 1800 / 3000: loss 2.681933
# iteration 1900 / 3000: loss 2.406848
# iteration 2000 / 3000: loss 2.535595
# iteration 2100 / 3000: loss 2.665769
# iteration 2200 / 3000: loss 2.670555
# iteration 2300 / 3000: loss 2.536819
# iteration 2400 / 3000: loss 2.456985
# iteration 2500 / 3000: loss 2.240601
# iteration 2600 / 3000: loss 2.332547
# iteration 2700 / 3000: loss 2.453659
# iteration 2800 / 3000: loss 2.284068
# iteration 2900 / 3000: loss 2.378398
# iteration 0 / 3000: loss 5.639095
# iteration 100 / 3000: loss 4.225586
# iteration 200 / 3000: loss 3.669003
# iteration 300 / 3000: loss 3.588410
# iteration 400 / 3000: loss 3.630516
# iteration 500 / 3000: loss 2.882041
# iteration 600 / 3000: loss 3.075193
# iteration 700 / 3000: loss 3.285350
# iteration 800 / 3000: loss 2.830559
# iteration 900 / 3000: loss 2.905847
# iteration 1000 / 3000: loss 2.718945
# iteration 1100 / 3000: loss 3.199537
# iteration 1200 / 3000: loss 2.957066
# iteration 1300 / 3000: loss 2.695769
# iteration 1400 / 3000: loss 2.587429
# iteration 1500 / 3000: loss 2.503229
# iteration 1600 / 3000: loss 2.752787
# iteration 1700 / 3000: loss 2.527676
# iteration 1800 / 3000: loss 2.642907
# iteration 1900 / 3000: loss 2.353927
# iteration 2000 / 3000: loss 2.623732
# iteration 2100 / 3000: loss 2.512294
# iteration 2200 / 3000: loss 2.745966
# iteration 2300 / 3000: loss 2.533482
# iteration 2400 / 3000: loss 2.725537
# iteration 2500 / 3000: loss 2.504189
# iteration 2600 / 3000: loss 2.225067
# iteration 2700 / 3000: loss 2.590128
# iteration 2800 / 3000: loss 2.530348
# iteration 2900 / 3000: loss 2.242976
# iteration 0 / 3000: loss 5.831447
# iteration 100 / 3000: loss 3.536215
# iteration 200 / 3000: loss 3.318605
# iteration 300 / 3000: loss 3.288184
# iteration 400 / 3000: loss 3.118414
# iteration 500 / 3000: loss 2.585477
# iteration 600 / 3000: loss 2.825973
# iteration 700 / 3000: loss 2.676244
# iteration 800 / 3000: loss 2.792317
# iteration 900 / 3000: loss 2.686390
# iteration 1000 / 3000: loss 2.641644
# iteration 1100 / 3000: loss 2.496519
# iteration 1200 / 3000: loss 2.718843
# iteration 1300 / 3000: loss 2.737446
# iteration 1400 / 3000: loss 2.733674
# iteration 1500 / 3000: loss 2.572466
# iteration 1600 / 3000: loss 2.570366
# iteration 1700 / 3000: loss 2.688410
# iteration 1800 / 3000: loss 2.276281
# iteration 1900 / 3000: loss 2.289287
# iteration 2000 / 3000: loss 2.686814
# iteration 2100 / 3000: loss 2.534228
# iteration 2200 / 3000: loss 2.235577
# iteration 2300 / 3000: loss 2.483134
# iteration 2400 / 3000: loss 2.642633
# iteration 2500 / 3000: loss 2.486801
# iteration 2600 / 3000: loss 2.412823
# iteration 2700 / 3000: loss 2.436514
# iteration 2800 / 3000: loss 2.499224
# iteration 2900 / 3000: loss 2.337171
# iteration 0 / 3000: loss 5.846549
# iteration 100 / 3000: loss 4.646972
# iteration 200 / 3000: loss 3.693910
# iteration 300 / 3000: loss 3.247901
# iteration 400 / 3000: loss 3.363797
# iteration 500 / 3000: loss 3.205953
# iteration 600 / 3000: loss 3.093529
# iteration 700 / 3000: loss 2.906538
# iteration 800 / 3000: loss 3.118908
# iteration 900 / 3000: loss 2.792379
# iteration 1000 / 3000: loss 2.801712
# iteration 1100 / 3000: loss 2.917765
# iteration 1200 / 3000: loss 2.619841
# iteration 1300 / 3000: loss 2.549037
# iteration 1400 / 3000: loss 2.845782
# iteration 1500 / 3000: loss 2.825689
# iteration 1600 / 3000: loss 2.590125
# iteration 1700 / 3000: loss 2.462561
# iteration 1800 / 3000: loss 2.444108
# iteration 1900 / 3000: loss 2.590571
# iteration 2000 / 3000: loss 2.470770
# iteration 2100 / 3000: loss 2.546297
# iteration 2200 / 3000: loss 2.389668
# iteration 2300 / 3000: loss 2.385357
# iteration 2400 / 3000: loss 2.480407
# iteration 2500 / 3000: loss 2.619694
# iteration 2600 / 3000: loss 2.660989
# iteration 2700 / 3000: loss 2.417267
# iteration 2800 / 3000: loss 2.586682
# iteration 2900 / 3000: loss 2.398494
# iteration 0 / 3000: loss 6.197142
# iteration 100 / 3000: loss 3.568472
# iteration 200 / 3000: loss 3.287834
# iteration 300 / 3000: loss 3.156558
# iteration 400 / 3000: loss 2.895393
# iteration 500 / 3000: loss 2.747834
# iteration 600 / 3000: loss 2.671282
# iteration 700 / 3000: loss 2.445322
# iteration 800 / 3000: loss 2.588335
# iteration 900 / 3000: loss 2.622498
# iteration 1000 / 3000: loss 2.391593
# iteration 1100 / 3000: loss 2.246648
# iteration 1200 / 3000: loss 2.375207
# iteration 1300 / 3000: loss 2.431881
# iteration 1400 / 3000: loss 2.425750
# iteration 1500 / 3000: loss 2.507435
# iteration 1600 / 3000: loss 2.349681
# iteration 1700 / 3000: loss 2.462859
# iteration 1800 / 3000: loss 2.117317
# iteration 1900 / 3000: loss 2.352767
# iteration 2000 / 3000: loss 2.113047
# iteration 2100 / 3000: loss 2.153968
# iteration 2200 / 3000: loss 2.366897
# iteration 2300 / 3000: loss 1.937766
# iteration 2400 / 3000: loss 2.155063
# iteration 2500 / 3000: loss 2.275693
# iteration 2600 / 3000: loss 2.310796
# iteration 2700 / 3000: loss 2.332768
# iteration 2800 / 3000: loss 1.997969
# iteration 2900 / 3000: loss 1.930458
# iteration 0 / 3000: loss 5.057820
# iteration 100 / 3000: loss 3.320035
# iteration 200 / 3000: loss 3.273052
# iteration 300 / 3000: loss 2.862969
# iteration 400 / 3000: loss 3.001891
# iteration 500 / 3000: loss 2.950014
# iteration 600 / 3000: loss 2.824986
# iteration 700 / 3000: loss 2.584936
# iteration 800 / 3000: loss 2.570616
# iteration 900 / 3000: loss 2.729051
# iteration 1000 / 3000: loss 2.403778
# iteration 1100 / 3000: loss 2.542619
# iteration 1200 / 3000: loss 2.601770
# iteration 1300 / 3000: loss 2.327592
# iteration 1400 / 3000: loss 2.526204
# iteration 1500 / 3000: loss 2.415110
# iteration 1600 / 3000: loss 2.430047
# iteration 1700 / 3000: loss 2.140651
# iteration 1800 / 3000: loss 2.446935
# iteration 1900 / 3000: loss 2.298156
# iteration 2000 / 3000: loss 2.313016
# iteration 2100 / 3000: loss 2.316784
# iteration 2200 / 3000: loss 2.178244
# iteration 2300 / 3000: loss 2.390231
# iteration 2400 / 3000: loss 2.178621
# iteration 2500 / 3000: loss 2.398801
# iteration 2600 / 3000: loss 2.249125
# iteration 2700 / 3000: loss 2.257771
# iteration 2800 / 3000: loss 2.184041
# iteration 2900 / 3000: loss 2.150802
# iteration 0 / 3000: loss 5.718224
# iteration 100 / 3000: loss 3.473429
# iteration 200 / 3000: loss 3.229091
# iteration 300 / 3000: loss 2.867793
# iteration 400 / 3000: loss 2.724872
# iteration 500 / 3000: loss 2.840892
# iteration 600 / 3000: loss 2.635901
# iteration 700 / 3000: loss 2.850618
# iteration 800 / 3000: loss 2.713395
# iteration 900 / 3000: loss 2.362610
# iteration 1000 / 3000: loss 2.464337
# iteration 1100 / 3000: loss 2.565363
# iteration 1200 / 3000: loss 2.332916
# iteration 1300 / 3000: loss 2.496779
# iteration 1400 / 3000: loss 2.151089
# iteration 1500 / 3000: loss 2.549721
# iteration 1600 / 3000: loss 2.302855
# iteration 1700 / 3000: loss 2.184623
# iteration 1800 / 3000: loss 2.210409
# iteration 1900 / 3000: loss 2.494324
# iteration 2000 / 3000: loss 2.455944
# iteration 2100 / 3000: loss 2.238184
# iteration 2200 / 3000: loss 2.324242
# iteration 2300 / 3000: loss 1.979731
# iteration 2400 / 3000: loss 2.234458
# iteration 2500 / 3000: loss 2.278534
# iteration 2600 / 3000: loss 2.103614
# iteration 2700 / 3000: loss 2.124785
# iteration 2800 / 3000: loss 2.095292
# iteration 2900 / 3000: loss 2.230002
# iteration 0 / 3000: loss 4.408240
# iteration 100 / 3000: loss 3.443369
# iteration 200 / 3000: loss 3.411273
# iteration 300 / 3000: loss 2.889130
# iteration 400 / 3000: loss 2.946352
# iteration 500 / 3000: loss 2.555920
# iteration 600 / 3000: loss 2.696120
# iteration 700 / 3000: loss 2.727467
# iteration 800 / 3000: loss 2.709221
# iteration 900 / 3000: loss 2.758217
# iteration 1000 / 3000: loss 2.461713
# iteration 1100 / 3000: loss 2.327299
# iteration 1200 / 3000: loss 2.326105
# iteration 1300 / 3000: loss 2.517425
# iteration 1400 / 3000: loss 2.388147
# iteration 1500 / 3000: loss 2.216031
# iteration 1600 / 3000: loss 2.427593
# iteration 1700 / 3000: loss 2.194068
# iteration 1800 / 3000: loss 2.134554
# iteration 1900 / 3000: loss 2.099224
# iteration 2000 / 3000: loss 2.163599
# iteration 2100 / 3000: loss 2.205219
# iteration 2200 / 3000: loss 2.194486
# iteration 2300 / 3000: loss 2.126764
# iteration 2400 / 3000: loss 2.134203
# iteration 2500 / 3000: loss 2.224228
# iteration 2600 / 3000: loss 2.115253
# iteration 2700 / 3000: loss 2.233699
# iteration 2800 / 3000: loss 2.010400
# iteration 2900 / 3000: loss 2.156741
# iteration 0 / 3000: loss 5.867257
# iteration 100 / 3000: loss 3.308485
# iteration 200 / 3000: loss 3.148770
# iteration 300 / 3000: loss 2.802742
# iteration 400 / 3000: loss 2.827245
# iteration 500 / 3000: loss 2.432019
# iteration 600 / 3000: loss 2.560503
# iteration 700 / 3000: loss 2.529188
# iteration 800 / 3000: loss 2.567346
# iteration 900 / 3000: loss 2.590983
# iteration 1000 / 3000: loss 2.275330
# iteration 1100 / 3000: loss 2.443208
# iteration 1200 / 3000: loss 2.301318
# iteration 1300 / 3000: loss 2.333380
# iteration 1400 / 3000: loss 2.225261
# iteration 1500 / 3000: loss 2.166491
# iteration 1600 / 3000: loss 2.142156
# iteration 1700 / 3000: loss 2.386879
# iteration 1800 / 3000: loss 2.272827
# iteration 1900 / 3000: loss 2.377109
# iteration 2000 / 3000: loss 2.093922
# iteration 2100 / 3000: loss 2.200732
# iteration 2200 / 3000: loss 2.241212
# iteration 2300 / 3000: loss 2.158829
# iteration 2400 / 3000: loss 2.231968
# iteration 2500 / 3000: loss 2.132549
# iteration 2600 / 3000: loss 2.050554
# iteration 2700 / 3000: loss 2.135319
# iteration 2800 / 3000: loss 1.974844
# iteration 2900 / 3000: loss 2.052280
# iteration 0 / 3000: loss 4.842740
# iteration 100 / 3000: loss 3.355342
# iteration 200 / 3000: loss 2.908875
# iteration 300 / 3000: loss 2.664810
# iteration 400 / 3000: loss 2.743102
# iteration 500 / 3000: loss 2.820867
# iteration 600 / 3000: loss 2.665579
# iteration 700 / 3000: loss 2.673153
# iteration 800 / 3000: loss 2.326716
# iteration 900 / 3000: loss 2.121003
# iteration 1000 / 3000: loss 2.302830
# iteration 1100 / 3000: loss 2.303010
# iteration 1200 / 3000: loss 2.262147
# iteration 1300 / 3000: loss 2.408256
# iteration 1400 / 3000: loss 2.294250
# iteration 1500 / 3000: loss 2.376916
# iteration 1600 / 3000: loss 2.285785
# iteration 1700 / 3000: loss 2.442869
# iteration 1800 / 3000: loss 2.171868
# iteration 1900 / 3000: loss 2.334316
# iteration 2000 / 3000: loss 2.127487
# iteration 2100 / 3000: loss 2.061849
# iteration 2200 / 3000: loss 2.162349
# iteration 2300 / 3000: loss 2.075094
# iteration 2400 / 3000: loss 2.199998
# iteration 2500 / 3000: loss 2.099229
# iteration 2600 / 3000: loss 2.037729
# iteration 2700 / 3000: loss 2.086827
# iteration 2800 / 3000: loss 1.901701
# iteration 2900 / 3000: loss 2.232588
# iteration 0 / 3000: loss 5.230162
# iteration 100 / 3000: loss 3.108212
# iteration 200 / 3000: loss 3.255688
# iteration 300 / 3000: loss 2.639643
# iteration 400 / 3000: loss 2.586750
# iteration 500 / 3000: loss 2.559556
# iteration 600 / 3000: loss 2.459341
# iteration 700 / 3000: loss 2.388300
# iteration 800 / 3000: loss 2.627189
# iteration 900 / 3000: loss 2.302734
# iteration 1000 / 3000: loss 2.203056
# iteration 1100 / 3000: loss 2.189967
# iteration 1200 / 3000: loss 2.357434
# iteration 1300 / 3000: loss 2.266861
# iteration 1400 / 3000: loss 2.291601
# iteration 1500 / 3000: loss 2.292871
# iteration 1600 / 3000: loss 2.125445
# iteration 1700 / 3000: loss 2.175120
# iteration 1800 / 3000: loss 1.973723
# iteration 1900 / 3000: loss 2.156084
# iteration 2000 / 3000: loss 2.093246
# iteration 2100 / 3000: loss 2.017099
# iteration 2200 / 3000: loss 2.099868
# iteration 2300 / 3000: loss 2.011351
# iteration 2400 / 3000: loss 2.146328
# iteration 2500 / 3000: loss 2.097902
# iteration 2600 / 3000: loss 2.041664
# iteration 2700 / 3000: loss 2.128817
# iteration 2800 / 3000: loss 1.975254
# iteration 2900 / 3000: loss 1.997791
# iteration 0 / 3000: loss 5.600551
# iteration 100 / 3000: loss 3.377924
# iteration 200 / 3000: loss 2.903374
# iteration 300 / 3000: loss 3.052068
# iteration 400 / 3000: loss 2.524550
# iteration 500 / 3000: loss 2.691086
# iteration 600 / 3000: loss 2.684919
# iteration 700 / 3000: loss 2.421055
# iteration 800 / 3000: loss 2.394401
# iteration 900 / 3000: loss 2.618210
# iteration 1000 / 3000: loss 2.435517
# iteration 1100 / 3000: loss 2.155076
# iteration 1200 / 3000: loss 2.254139
# iteration 1300 / 3000: loss 2.411966
# iteration 1400 / 3000: loss 2.401581
# iteration 1500 / 3000: loss 2.246268
# iteration 1600 / 3000: loss 2.393453
# iteration 1700 / 3000: loss 2.122759
# iteration 1800 / 3000: loss 2.116038
# iteration 1900 / 3000: loss 2.162649
# iteration 2000 / 3000: loss 2.300216
# iteration 2100 / 3000: loss 2.271317
# iteration 2200 / 3000: loss 2.034555
# iteration 2300 / 3000: loss 2.069539
# iteration 2400 / 3000: loss 1.783266
# iteration 2500 / 3000: loss 2.023533
# iteration 2600 / 3000: loss 2.033074
# iteration 2700 / 3000: loss 2.090441
# iteration 2800 / 3000: loss 2.057603
# iteration 2900 / 3000: loss 1.991291
# lr 5.000000e-08 reg 1.250000e+04 train accuracy: 0.243510 val accuracy: 0.262000
# lr 5.000000e-08 reg 2.500000e+04 train accuracy: 0.249673 val accuracy: 0.257000
# lr 5.000000e-08 reg 5.000000e+04 train accuracy: 0.246694 val accuracy: 0.252000
# lr 5.000000e-08 reg 7.500000e+04 train accuracy: 0.252367 val accuracy: 0.246000
# lr 1.000000e-07 reg 1.250000e+04 train accuracy: 0.276571 val accuracy: 0.292000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.277449 val accuracy: 0.285000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.282878 val accuracy: 0.307000
# lr 1.000000e-07 reg 7.500000e+04 train accuracy: 0.276837 val accuracy: 0.278000
# lr 2.000000e-07 reg 1.250000e+04 train accuracy: 0.310531 val accuracy: 0.308000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.303245 val accuracy: 0.298000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.309776 val accuracy: 0.319000
# lr 2.000000e-07 reg 7.500000e+04 train accuracy: 0.305184 val accuracy: 0.316000
# lr 3.000000e-07 reg 1.250000e+04 train accuracy: 0.322082 val accuracy: 0.322000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.325388 val accuracy: 0.320000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.328306 val accuracy: 0.312000
# lr 3.000000e-07 reg 7.500000e+04 train accuracy: 0.328000 val accuracy: 0.330000
# best validation accuracy achieved during cross-validation: 0.330000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.288000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
